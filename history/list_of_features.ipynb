# %%
import pandas as pd
train_df = pd.read_csv('data/train_features_total.csv')

# %%
[c for c in train_df.columns.tolist() if c.startswith('r1')]
# Out:
# ['r1_chat_msg',
#  'r1_multi_kills_2',
#  'r1_multi_kills_>2',
#  'r1_kill_streaks_3-4',
#  'r1_kill_streaks_5-6',
#  'r1_kill_streaks_>6',
#  'r1_len_obs_left',
#  'r1_len_sen_left',
#  'r1_len_purchase',
#  'r1_n_buybacks',
#  'r1_xp_sec',
#  'r1_gold_sec',
#  'r1_x',
#  'r1_y',
#  'r1_lane',
#  'r1_my_base_d',
#  'r1_enemy_base_d',
#  'r1_action_0',
#  'r1_action_1',
#  'r1_action_2',
#  'r1_action_3',
#  'r1_action_4',
#  'r1_action_5',
#  'r1_action_6',
#  'r1_action_7',
#  'r1_action_8',
#  'r1_action_9',
#  'r1_action_10',
#  'r1_action_11',
#  'r1_action_12',
#  'r1_action_13',
#  'r1_action_14',
#  'r1_action_15',
#  'r1_action_16',
#  'r1_action_17',
#  'r1_action_18',
#  'r1_action_19',
#  'r1_action_20',
#  'r1_action_21',
#  'r1_action_23',
#  'r1_action_24',
#  'r1_action_25',
#  'r1_action_26',
#  'r1_action_27',
#  'r1_action_28',
#  'r1_action_29',
#  'r1_action_30',
#  'r1_action_31',
#  'r1_action_32',
#  'r1_action_33',
#  'r1_action_36',
#  'r1_sec_dead',
# ...
